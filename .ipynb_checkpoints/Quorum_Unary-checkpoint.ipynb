# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
class Agent:

    def __init__(self,p):
        (self.x, self.y) = np.random.random(2)

        self.evidence = 0.0

        if np.random.random() < p:
            self.decision = True
        else:
            self.decision = False

    def wrap(self):
        if self.x > 1:
            self.x -= 1
        elif self.x < 0:
            self.x += 1

        if self.y > 1:
            self.y -= 1
        elif self.y < 0:
            self.y += 1

# %%
def dist_matrix(S):

    DD = np.zeros((len(S),len(S)))
    for ii in range(len(S)):
        for jj in range(len(S)):
            if abs(S[ii].x - S[jj].x) < 0.5:
                xd = abs(S[ii].x - S[jj].x)
            else:
                xd = 1 - abs (S[ii].x - S[jj].x)
            if abs(S[ii].y - S[jj].y) < 0.5:
                yd = abs(S[ii].y - S[jj].y)
            else:
                yd = 1 - abs (S[ii].y - S[jj].y)
            DD[ii,jj] = np.sqrt(xd**2 + yd**2)
    return DD

# %%
def connect(S,threshold):

    D = dist_matrix(S)
    C = np.empty((len(D),len(D)), dtype = bool)

    for ii in range(len(D)):
        for jj in range(len(D)):
            if D[ii,jj] < threshold:
                C[ii,jj] = True
            else:
                C[ii,jj] = False

    return C

# %%
def gather_evidence(S,N,lam,tau):

    Dist = dist_matrix(S)
    for j in range(N):
        for k in range(N):
            if j != k:
                if S[k].decision == True:
                    S[j].evidence += lam/(Dist[j,k])
                    #S[j].evidence += np.exp(-lam * Dist[j,k]**2)

        S[j].evidence -= S[j].evidence * tau

# %%
def move(S,N,dr):

    for j in range(N):

        S[j].x += np.sqrt(dr)*np.random.randn()
        S[j].y += np.sqrt(dr)*np.random.randn()

        S[j].wrap()

# %%
def set_parameters(Total_Time=10000, dr=0.0001, N=100, lam=0.1, tau=0.018, prob=1.0):
    
    para = {
        
        'dr': dr,
        'total': Total_Time,
        'N': N,

        'lam': lam,
        'tau': tau,

        'prob': prob,
        
    }
    
    return para

# %%
def simulate(para):
    
    pos = np.zeros((para['total'],para['N'],2))

    ZZ = np.zeros(para['total'])

    Z = np.zeros((para['total'],para['N']))

    S = [Agent(para['prob']) for i in range(para['N'])]

    for i in tqdm(range(para['total'])):

        gather_evidence(S,para['N'],para['lam'],para['tau'])

        for j in range(para['N']):

            pos[i,j,0] = S[j].x
            pos[i,j,1] = S[j].y

            Z[i,j] = S[j].evidence

            move(S,para['N'],para['dr'])

    ZZ += np.mean(Z, axis=1)

    norm_factor = 1
    
    out = {
        'positions': pos,
        'evidence_individual': Z,
        'evidence_mean': ZZ
    }
    
    return out

# %%
def set_plotter_axes(size, xlabel, ylabel):
    plt.figure(figsize=size)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
def evidence_plotter(N, output, color, label):
    for i in range(N):
        plt.plot(output['evidence_individual'][:,i],color,alpha=0.03)
    plt.plot(output['evidence_mean'],color,label=label)

# %%
def position_plotter(N, output, index, ti, tf):
    plt.plot(output['positions'][ti:tf,index,0], output['positions'][ti:tf,index,1], '.r')
    plt.show()

# %%
def norm_factor(lam,N,tau):
    d = 0.52140543316472067833
    return lam*(N-1)/(d*np.exp(tau))

# %%
set_plotter_axes((10,10), 'Time', 'Evidence')
para = set_parameters(N=10)
output = simulate(para)
evidence_plotter(para['N'],output,'k','')
plt.show()
# Out:
# 100%|██████████| 10000/10000 [00:22<00:00, 439.77it/s]

# %%
set_plotter_axes((10,10), 'Time', 'Evidence')
pp = [0.20, 0.40, 0.60, 0.80, 1.00]
cc = ['r', 'g', 'b', 'm', 'c']
assert len(pp)==len(cc)
for i in range(len(pp)):
    para = set_parameters(N=50,prob=pp[i])
    output = simulate(para)
    ll = 'p = '+str(pp[i])
    evidence_plotter(para['N'],output,cc[i],ll)
plt.legend()
plt.savefig('Plot.png')
plt.savefig('Plot.pdf')
plt.show()
# Out:
# 100%|██████████| 10000/10000 [08:38<00:00, 19.54it/s]
#  37%|███▋      | 3732/10000 [03:20<05:40, 18.40it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-100-afb7a676fc91> in <module>
#       5 for i in range(len(pp)):
#       6     para = set_parameters(N=50,prob=pp[i])
# ----> 7     output = simulate(para)
#       8     ll = 'p = '+str(pp[i])
#       9     evidence_plotter(para['N'],output,cc[i],ll)
#
# <ipython-input-92-0b41df9fe978> in simulate(para)
#      20             Z[i,j] = S[j].evidence
#      21
# ---> 22             move(S,para['N'],para['dr'])
#      23
#      24     ZZ += np.mean(Z, axis=1)
#
# <ipython-input-90-a04e4f120b18> in move(S, N, dr)
#       6         S[j].y += np.sqrt(dr)*np.random.randn()
#       7
# ----> 8         S[j].wrap()
#
# <ipython-input-86-50f85c37ba4a> in wrap(self)
#      12
#      13     def wrap(self):
# ---> 14         if self.x > 1:
#      15             self.x -= 1
#      16         elif self.x < 0:
#
# KeyboardInterrupt:

# %%
position_plotter(10,output,4,0,10000)
